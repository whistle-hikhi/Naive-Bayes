# %% [markdown]
# <a href="https://colab.research.google.com/github/whistle-hikhi/Naive-Bayes/blob/main/naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Apr  2 09:47:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %load_ext cuml.accel
# Out:
# [2025-04-02 09:47:54.980] [CUML] [info] cuML: Installed accelerator for sklearn.
# [2025-04-02 09:48:36.169] [CUML] [info] cuML: Installed accelerator for umap.
# [2025-04-02 09:48:36.259] [CUML] [info] cuML: Installed accelerator for hdbscan.
# [2025-04-02 09:48:36.259] [CUML] [info] cuML: Successfully initialized accelerator.

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
categories = ['alt.atheism', 'soc.religion.christian', 'comp.graphics', 'sci.med']
news_data = fetch_20newsgroups(subset='train', categories=categories, shuffle=True)

vectorizer = TfidfVectorizer(max_features=5000)
X = vectorizer.fit_transform(news_data.data)
y = news_data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# %%time
mnb = MultinomialNB()
mnb.fit(X_train, y_train)
# Out:
# CPU times: user 6.47 ms, sys: 0 ns, total: 6.47 ms
# Wall time: 7.25 ms
# MultinomialNB()

# %%
y_pred = mnb.predict(X_test)

# %%
print(classification_report(y_test, y_pred, target_names=categories))
# Out:
#                         precision    recall  f1-score   support
#
#            alt.atheism       1.00      0.84      0.91        89
# soc.religion.christian       0.97      0.99      0.98       128
#          comp.graphics       0.97      0.97      0.97       109
#                sci.med       0.90      0.98      0.94       126
#
#               accuracy                           0.95       452
#              macro avg       0.96      0.95      0.95       452
#           weighted avg       0.96      0.95      0.95       452
